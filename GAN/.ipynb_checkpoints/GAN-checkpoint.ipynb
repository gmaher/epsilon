# %%
# %matplotlib inline
import numpy as np
import tensorflow as tf
from PIL import Image
import os
import matplotlib.pyplot as plt

# %%
#create training data

# %%
folder = "./bmw10_release/bmw10_ims/"

Npixels = 25
Nchannels = 3

cars = []

for d in os.listdir(folder):
    for f in os.listdir(folder+d):
        img = Image.open(folder+d+'/'+f)
        
        img = img.resize((Npixels, Npixels))
        
        cars.append(np.asarray(img))
        
cars = np.asarray(cars)
print cars.shape

NUM_CARS = cars.shape[0]
# Out:
# (512, 25, 25, 3)

# %%
#plot some random images
Num_images_to_plot = 5
for i in range(0,Num_images_to_plot):
    index = np.random.randint(NUM_CARS)
    
    plt.imshow(cars[index,:])
    plt.show()

# %%
#normalize data

# %%
means = np.mean(cars, axis=(0,1,2))
stdevs = np.std(cars,axis=(0,1,2))

print means
print stdevs

cars_norm = (cars-means)/stdevs

print np.mean(cars_norm, axis=(0,1,2))
print np.std(cars_norm,axis=(0,1,2))
# Out:
# [ 116.94784687  117.20950312  115.99665312]
# [ 72.07456184  71.47683711  73.89948193]
# [  8.69663890e-16  -1.23780049e-15   1.62429514e-15]
# [ 1.  1.  1.]

# %%
#define network structure
NBATCH = 100
W_init = 0.01

G_Nunits1 = 10

# %%
x = tf.placeholder(tf.float32, shape=(NBATCH,Npixels,Npixels,Nchannels))
z = tf.placeholder(tf.float32, shape=(NBATCH,1))

# %%
#generator network

# %%
G_w1 = tf.Variable(
    tf.random_normal(shape=(1,G_Nunits1),stddev=W_init)
)

G_b1 = tf.Variable(
    tf.zeros(shape=(1,G_Nunits1))
)

G_hidden1 = tf.nn.relu(tf.matmul(z,G_w1)+G_b1)

G_w2 = tf.Variable(
    tf.random_normal(shape=(G_Nunits1, Npixels*Npixels*Nchannels),stddev=W_init)
)

G_b2 = tf.Variable(
    tf.zeros(shape=(1, Npixels*Npixels*Nchannels))
)

G_out = tf.reshape(
    tf.matmul(G_hidden1, G_w2)+G_b2,
    shape=(NBATCH,Npixels,Npixels,Nchannels)
)

# %%
#Discriminator network
Nfilters = 6
Conv_Shape = 3
strides = [1,1,1,1]

# %%
D_w1 = tf.Variable(
    tf.random_normal(shape=(Conv_Shape,Conv_Shape,Nchannels,Nfilters),
                    stddev=W_init
                    )
)

D_b1 = tf.Variable(
    tf.zeros(shape=[Nfilters])
)

D_w2 = tf.Variable(
    tf.random_normal(shape=(Conv_Shape,Conv_Shape,Nfilters,Nfilters),
                    stddev=W_init
                    )
)

D_b2 = tf.Variable(
    tf.zeros(shape=[Nfilters])
)

D_w3 = tf.Variable(
    tf.random_normal(shape=(Nfilters*Npixels**2,1),
                    stddev=W_init
                    )
)

D_b3 = tf.Variable(
    tf.zeros(shape=(1,Nfilters*Npixels**2))
)

# %%
#pass real data through discriminator
def Pass_through_discriminator(x_in):
    D_real_out1 = tf.nn.conv2d(x_in, D_w1, strides, padding="SAME")
    D_real_out1 = tf.nn.bias_add(D_real_out1, D_b1)
    D_real_out1 = tf.nn.relu(D_real_out1)

    D_real_out2 = tf.nn.conv2d(D_real_out1, D_w2, strides, padding="SAME")
    D_real_out2 = tf.nn.bias_add(D_real_out2, D_b2)
    D_real_out2 = tf.nn.relu(D_real_out2)

    D_real_out3 = tf.reshape(D_real_out2,[NBATCH,-1])
    D_real_out3 = tf.matmul(D_real_out3,D_w3)+D_b3
    D_real_out3 = tf.nn.sigmoid(D_real_out3)
    
    return D_real_out3

# %%
real_out = Pass_through_discriminator(x)

fake_out = Pass_through_discriminator(G_out)

# %%
#loss functions

# %%
D_loss = -tf.reduce_mean(tf.log(real_out)) -\
tf.reduce_mean(tf.log(1-fake_out))

G_loss1 = -tf.reduce_mean(tf.log(fake_out))

G_loss2 = tf.reduce_mean(tf.log(1-fake_out))

# %%
#set up optimization
lr = 1e-3
momentum = 0.9

# %%
opt = tf.train.MomentumOptimizer(lr,momentum)

D_train = opt.minimize(D_loss, var_list=[D_w1,D_b1,D_w2,D_b2,D_w3,D_b3])

G_train1 = opt.minimize(G_loss1, var_list=[G_w1,G_b1,G_w2,G_b2])

G_train2 = opt.minimize(G_loss2, var_list=[G_w1,G_b1,G_w2,G_b2])

# %%
#set up session and initialize
init = tf.initialize_all_variables()
sess = tf.Session()
sess.run(init)

# %%
#set up training loop
Niter1 = 10000
Niter2 = 10000
kd = 1
kg = 1
print_step = 1000

def get_batch(xdata, nbatch):
    N = xdata.shape[0]
    inds = np.random.choice(N, size=nbatch, replace=False)
    xret = xdata[inds,:]

    return xret

# %%
#training loop 1
for step in xrange(Niter1+1):

    for i in range(0,kd):    
        x_batch = get_batch(cars_norm, NBATCH)
        z_batch = np.random.rand(NBATCH,1)
        
        sess.run(D_train,feed_dict={x:x_batch,z:z_batch})
    
    for i in range(0,kg):
        z_batch = np.random.rand(NBATCH,1)
        
        sess.run(G_train1, feed_dict={z:z_batch})
        
    if step % print_step == 0:
        dl=sess.run(D_loss,feed_dict={x:x_batch,z:z_batch})
        gl=sess.run(G_loss1,feed_dict={z:z_batch})

        print "Discriminator loss: ", dl, ", Generator loss: ", gl
# Out:
# Discriminator loss:  1.3854 , Generator loss:  0.692376
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-d2b02fd50d4a> in <module>()
#       6         z_batch = np.random.rand(NBATCH,1)
#       7
# ----> 8         sess.run(D_train,feed_dict={x:x_batch,z:z_batch})
#       9
#      10     for i in range(0,kg):
#
# /home/gabriel/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     331     try:
#     332       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 333                          run_metadata_ptr)
#     334       if run_metadata:
#     335         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/gabriel/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     571     try:
#     572       results = self._do_run(handle, target_list, unique_fetches,
# --> 573                              feed_dict_string, options, run_metadata)
#     574     finally:
#     575       # The movers are no longer used. Delete them.
#
# /home/gabriel/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     651     if handle is None:
#     652       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 653                            target_list, options, run_metadata)
#     654     else:
#     655       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/gabriel/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     658   def _do_call(self, fn, *args):
#     659     try:
# --> 660       return fn(*args)
#     661     except errors.OpError as e:
#     662       message = compat.as_text(e.message)
#
# /home/gabriel/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     640           return tf_session.TF_Run(
#     641               session, None, feed_dict, fetch_list, target_list, status,
# --> 642               None)
#     643
#     644     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#training loop 2
for step in xrange(Niter2+1):
    
    for i in range(0,kd):
        x_batch = get_batch(cars_norm, NBATCH)
        z_batch = np.random.rand(NBATCH,1)
    
        sess.run(D_train,feed_dict={x:x_batch,z:z_batch})
    
        #dl=sess.run(D_loss,feed_dict={x:x_batch,z:z_batch})
        #gl=sess.run(G_loss2,feed_dict={z:z_batch})
        
        #print "Discriminator loss: ", dl, ", Generator loss: ", gl
    
    for i in range(0,kg):
        z_batch = np.random.rand(NBATCH,1)
        sess.run(G_train2, feed_dict={z:z_batch})
        
    if step % print_step == 0:
        dl=sess.run(D_loss,feed_dict={x:x_batch,z:z_batch})
        gl=sess.run(G_loss2,feed_dict={z:z_batch})

        print "Discriminator loss: ", dl, ", Generator loss: ", gl
# Out:
# Discriminator
#
# Discriminator loss:  1.0916 , Generator loss:  -0.627732
# Discriminator loss:  1.0637 , Generator loss:  -0.622015
# Discriminator loss:  1.00903 , Generator loss:  -0.615879
# Discriminator loss:  0.98709 , Generator loss:  -0.609684
# Discriminator loss:  0.939935 , Generator loss:  -0.602222
# Discriminator loss:  0.903777 , Generator loss:  -0.593697
# Discriminator loss:  0.842505 , Generator loss:  -0.584072
# Discriminator loss:  0.793813 , Generator loss:  -0.573164
# Discriminator loss:  0.752542 , Generator loss:  -0.561596
# Discriminator loss:  0.714517 , Generator loss:  -0.548692
# Generator
#
# Discriminator loss:  0.71452 , Generator loss:  -0.548695
# Discriminator loss:  0.715629 , Generator loss:  -0.549804
# Discriminator loss:  0.717034 , Generator loss:  -0.551209
# Discriminator loss:  0.71867 , Generator loss:  -0.552845
# Discriminator loss:  0.720489 , Generator loss:  -0.554664
# Discriminator loss:  0.722461 , Generator loss:  -0.556637
# Discriminator loss:  0.724599 , Generator loss:  -0.558774
# Discriminator loss:  0.726887 , Generator loss:  -0.561063
# Discriminator loss:  0.729325 , Generator loss:  -0.5635
# Discriminator loss:  0.731877 , Generator loss:  -0.566053
# Discriminator
#
# Discriminator loss:  0.697605 , Generator loss:  -0.554237
# Discriminator loss:  0.664269 , Generator loss:  -0.536706
# Discriminator loss:  0.616787 , Generator loss:  -0.516355
# Discriminator loss:  0.569501 , Generator loss:  -0.493591
# Discriminator loss:  0.545776 , Generator loss:  -0.469223
# Discriminator loss:  0.517493 , Generator loss:  -0.443979
# Discriminator loss:  0.47935 , Generator loss:  -0.418086
# Discriminator loss:  0.446239 , Generator loss:  -0.391751
# Discriminator loss:  0.406179 , Generator loss:  -0.365015
# Discriminator loss:  0.385655 , Generator loss:  -0.338134
# Generator
#
# Discriminator loss:  0.385656 , Generator loss:  -0.338135
# Discriminator loss:  0.385816 , Generator loss:  -0.338296
# Discriminator loss:  0.386065 , Generator loss:  -0.338545
# Discriminator loss:  0.386486 , Generator loss:  -0.338965
# Discriminator loss:  0.387125 , Generator loss:  -0.339604
# Discriminator loss:  0.387974 , Generator loss:  -0.340453
# Discriminator loss:  0.389109 , Generator loss:  -0.341588
# Discriminator loss:  0.390576 , Generator loss:  -0.343056
# Discriminator loss:  0.392281 , Generator loss:  -0.34476
# Discriminator loss:  0.394265 , Generator loss:  -0.346744
# Discriminator
#
# Discriminator loss:  0.362926 , Generator loss:  -0.32025
# Discriminator loss:  0.329846 , Generator loss:  -0.291641
# Discriminator loss:  0.297412 , Generator loss:  -0.263617
# Discriminator loss:  0.267938 , Generator loss:  -0.236584
# Discriminator loss:  0.242107 , Generator loss:  -0.210976
# Discriminator loss:  0.2155 , Generator loss:  -0.187066
# Discriminator loss:  0.192316 , Generator loss:  -0.165068
# Discriminator loss:  0.174055 , Generator loss:  -0.145141
# Discriminator loss:  0.156878 , Generator loss:  -0.127316
# Discriminator loss:  0.146269 , Generator loss:  -0.111587
# Generator
#
# Discriminator loss:  0.146276 , Generator loss:  -0.111595
# Discriminator loss:  0.146515 , Generator loss:  -0.111833
# Discriminator loss:  0.146744 , Generator loss:  -0.112063
# Discriminator loss:  0.147005 , Generator loss:  -0.112324
# Discriminator loss:  0.147291 , Generator loss:  -0.11261
# Discriminator loss:  0.14759 , Generator loss:  -0.112909
# Discriminator loss:  0.147921 , Generator loss:  -0.113239
# Discriminator loss:  0.14828 , Generator loss:  -0.113598
# Discriminator loss:  0.148671 , Generator loss:  -0.113989
# Discriminator loss:  0.1491 , Generator loss:  -0.114419
# Discriminator
#
# Discriminator loss:  0.133947 , Generator loss:  -0.100708
# Discriminator loss:  0.111915 , Generator loss:  -0.0883175
# Discriminator loss:  0.100531 , Generator loss:  -0.0775509
# Discriminator loss:  0.0931018 , Generator loss:  -0.0682781
# Discriminator loss:  0.0832006 , Generator loss:  -0.0603018
# Discriminator loss:  0.0700815 , Generator loss:  -0.0534404
# Discriminator loss:  0.0652797 , Generator loss:  -0.0475596
# Discriminator loss:  0.0618406 , Generator loss:  -0.0425213
# Discriminator loss:  0.0597422 , Generator loss:  -0.0382323
# Discriminator loss:  0.0549316 , Generator loss:  -0.0345806
# Generator
#
# Discriminator loss:  0.0549268 , Generator loss:  -0.0345758
# Discriminator loss:  0.0550111 , Generator loss:  -0.03466
# Discriminator loss:  0.0550753 , Generator loss:  -0.0347242
# Discriminator loss:  0.055152 , Generator loss:  -0.0348009
# Discriminator loss:  0.0552295 , Generator loss:  -0.0348784
# Discriminator loss:  0.0552981 , Generator loss:  -0.0349471
# Discriminator loss:  0.0553805 , Generator loss:  -0.0350294
# Discriminator loss:  0.0554672 , Generator loss:  -0.0351162
# Discriminator loss:  0.0555431 , Generator loss:  -0.035192
# Discriminator loss:  0.0556274 , Generator loss:  -0.0352764
# Discriminator
#
# Discriminator loss:  0.0478328 , Generator loss:  -0.0321612
# Discriminator loss:  0.0425963 , Generator loss:  -0.0293971
# Discriminator loss:  0.0419001 , Generator loss:  -0.0270016
# Discriminator loss:  0.0368346 , Generator loss:  -0.0249285
# Discriminator loss:  0.0351013 , Generator loss:  -0.0231133
# Discriminator loss:  0.0304599 , Generator loss:  -0.021524
# Discriminator loss:  0.0346443 , Generator loss:  -0.0201419
# Discriminator loss:  0.0281921 , Generator loss:  -0.0189258
# Discriminator loss:  0.0229891 , Generator loss:  -0.0178352
# Discriminator loss:  0.0277401 , Generator loss:  -0.016877
# Generator
#
# Discriminator loss:  0.0277422 , Generator loss:  -0.016879
# Discriminator loss:  0.0277758 , Generator loss:  -0.0169126
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-164-6c545986f00b> in <module>()
#      17     for i in range(0,kg):
#      18         z_batch = np.random.rand(NBATCH,1)
# ---> 19         sess.run(G_train2, feed_dict={z:z_batch})
#      20
#      21         if i % print_step == 0:
#
# /home/gabriel/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     331     try:
#     332       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 333                          run_metadata_ptr)
#     334       if run_metadata:
#     335         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/gabriel/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     571     try:
#     572       results = self._do_run(handle, target_list, unique_fetches,
# --> 573                              feed_dict_string, options, run_metadata)
#     574     finally:
#     575       # The movers are no longer used. Delete them.
#
# /home/gabriel/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     651     if handle is None:
#     652       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 653                            target_list, options, run_metadata)
#     654     else:
#     655       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/gabriel/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     658   def _do_call(self, fn, *args):
#     659     try:
# --> 660       return fn(*args)
#     661     except errors.OpError as e:
#     662       message = compat.as_text(e.message)
#
# /home/gabriel/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     640           return tf_session.TF_Run(
#     641               session, None, feed_dict, fetch_list, target_list, status,
# --> 642               None)
#     643
#     644     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#generate some cars

# %%
z_batch = np.random.rand(NBATCH,1)

gen_cars = sess.run(G_out, feed_dict={z:z_batch})
print gen_cars.shape
#plot some random images
Num_images_to_plot = 5
for i in range(0,Num_images_to_plot):
    index = np.random.randint(NBATCH)
    
    plt.imshow((gen_cars[index,:]*stdevs)+means)
    plt.show()
# Out:
# (100, 25, 25, 3)
